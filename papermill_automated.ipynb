# %%
import papermill as pm
pm.execute_notebook('sales_template.ipynb', 'Outputs/February_sales.ipynb', 
                   parameters=dict(filename='Data/sales_february.xlsx'))
# Out:
# ...
# {u'cells': [{u'cell_type': u'markdown',
#    u'metadata': {u'colab_type': u'text',
#     u'id': u'view-in-github',
#     u'papermill': {'duration': 0.021374,
#      'end_time': '2019-08-08T03:39:41.198469',
#      'exception': False,
#      'start_time': '2019-08-08T03:39:41.177095',
#      'status': 'completed'},
#     u'tags': []},
#    u'source': u'<a href="https://colab.research.google.com/github/SaashaJoshi/automated-report-generation/blob/master/January_sales_localxlsx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>'},
#   {u'cell_type': u'code',
#    u'execution_count': 1,
#    u'metadata': {u'colab': {u'base_uri': u'https://localhost:8080/',
#      u'height': 74,
#      u'resources': {u'http://localhost:8080/nbextensions/google.colab/files.js': {u'data': u'...',
#        u'headers': [[u'content-type', u'application/javascript']],
#        u'ok': True,
#        u'status': 200,
# ...

# %%
import pprint
pprint()
